# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('energydata_complete.csv')

# %%
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df1 = df.drop(columns = 'date')
df1
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
df1.head()
# Out:
#    Appliances  lights     T1       RH_1    T2       RH_2     T3       RH_3  \
# 0          60      30  19.89  47.596667  19.2  44.790000  19.79  44.730000
# 1          60      30  19.89  46.693333  19.2  44.722500  19.79  44.790000
# 2          50      30  19.89  46.300000  19.2  44.626667  19.79  44.933333
# 3          50      40  19.89  46.066667  19.2  44.590000  19.79  45.000000
# 4          60      40  19.89  46.333333  19.2  44.530000  19.79  45.000000
#
#           T4       RH_4  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  19.000000  45.566667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  19.000000  45.992500  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  18.926667  45.890000  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  18.890000  45.723333  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  18.890000  45.530000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
df1.tail()
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3    T4       RH_4  ...    T9     RH_9      T_out  \
# 19730  27.200000  41.163333  24.7  45.590000  ...  23.2  46.7900  22.733333
# 19731  27.133333  41.223333  24.7  45.590000  ...  23.2  46.7900  22.600000
# 19732  27.050000  41.690000  24.7  45.730000  ...  23.2  46.7900  22.466667
# 19733  26.890000  41.290000  24.7  45.790000  ...  23.2  46.8175  22.333333
# 19734  26.823333  41.156667  24.7  45.963333  ...  23.2  46.8450  22.200000
#
#        Press_mm_hg     RH_out  Windspeed  Visibility  Tdewpoint        rv1  \
# ...

# %%
df1.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %%
sample_df = df1[['T2', 'T6']].sample(100, random_state=42)
sns.regplot(x="T2", y="T6",data=sample_df)
plt.xlabel('Temperature in the Living Room')
plt.ylabel('Temperature outside the Building')
# Out:
# Text(0, 0.5, 'Temperature outside the Building')

# %% [markdown]
# # Q12

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

normalised_df_1 = pd.DataFrame(scaler.fit_transform(df1), columns=df1.columns)

feature_variable_1 = normalised_df_1['T2']
target_variable_1 = normalised_df_1['T6']

# %%
from sklearn.model_selection import train_test_split
x_train_1, x_test_1, y_train_1, y_test_1 = train_test_split(feature_variable_1, target_variable_1, test_size=0.70, random_state=42)

x_train_1 = x_train_1.values.reshape(-1, 1)
y_train_1 = y_train_1.values.reshape(-1, 1)
x_test_1 = x_test_1.values.reshape(-1, 1)
y_test_1 = y_test_1.values.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()

linear_model.fit(x_train_1, y_train_1)

predicted_values_1 = linear_model.predict(x_test_1)

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test_1, predicted_values_1)
round(r2_score, 2)
# Out:
# 0.64

# %% [markdown]
# # Q13

# %%
df2 = df.drop(columns = ['date', 'lights'])
df2
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

normalised_df_2 = pd.DataFrame(scaler.fit_transform(df2), columns=df2.columns)

feature_variable_2_df = normalised_df_2.drop(columns='Appliances')
target_variable_2 = normalised_df_2['Appliances']

# %%
from sklearn.model_selection import train_test_split
x_train_2, x_test_2, y_train_2, y_test_2 = train_test_split(feature_variable_2_df, target_variable_2, test_size=0.70, random_state=42)

linear_model.fit(x_train_2, y_train_2)

predicted_values_2 = linear_model.predict(x_test_2)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test_2, predicted_values_2)
round(mae, 2)
# Out:
# 0.05

# %% [markdown]
# # Q14

# %%
rss = np.sum(np.square(y_test_2 - predicted_values_2))
round(rss, 2)
# Out:
# 111.0

# %% [markdown]
# # Q15

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test_2, predicted_values_2))
print(round(rmse, 3))
# Out:
# 0.09

# %% [markdown]
# # Q16

# %% [markdown]
# ###### Coefficient of determination is R^2 score

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test_2, predicted_values_2)
round(r2_score, 2)
# Out:
# 0.14

# %% [markdown]
# # Q17

# %%
def get_weights_df(model, feat, col_name):

    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
linear_model_weights = get_weights_df(linear_model, x_train_2, 'Linear_Model_Weight')
linear_model_weights
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.422484
# 1         T_out            -0.243451
# 2            T2            -0.241125
# 3            T9            -0.181327
# 4          RH_8            -0.173404
# 5        RH_out            -0.043873
# 6          RH_9            -0.028465
# 7            T5            -0.023826
# 8          RH_7            -0.023157
# 9          RH_4            -0.020727
# 10           T7            -0.008981
# 11          rv2            -0.000730
# 12          rv1            -0.000730
# 13           T1             0.004817
# 14  Press_mm_hg             0.013672
# 15   Visibility             0.016239
# 16         RH_5             0.023723
# 17           T4             0.029408
# 18    Windspeed             0.035072
# 19         RH_6             0.044838
# 20    Tdewpoint             0.068642
# 21         RH_3             0.098584
# 22           T8             0.113388
# 23           T6             0.236490
# ...

# %% [markdown]
# ### Max = RH_1(0.558100) , Min = RH_2(-0.422484)

# %% [markdown]
# # Q18

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

normalised_df_3 = pd.DataFrame(scaler.fit_transform(df2), columns=df2.columns)

feature_variable_3_df = normalised_df_3.drop(columns='Appliances')
target_variable_3 = normalised_df_3['Appliances']

# %%
from sklearn.model_selection import train_test_split
x_train_3, x_test_3, y_train_3, y_test_3 = train_test_split(feature_variable_3_df, target_variable_3, test_size=0.70, random_state=42)

from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train_3, y_train_3)

predicted_values_3 = ridge_reg.predict(x_test_3)

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test_3, predicted_values_3))
round(rmse, 9)
# Out:
# 0.089704615

# %% [markdown]
# # Q19

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

normalised_df_4 = pd.DataFrame(scaler.fit_transform(df2), columns=df2.columns)

feature_variable_4_df = normalised_df_4.drop(columns='Appliances')
target_variable_4 = normalised_df_4['Appliances']

# %%
from sklearn.model_selection import train_test_split
x_train_4, x_test_4, y_train_4, y_test_4 = train_test_split(feature_variable_4_df, target_variable_4, test_size=0.70, random_state=42)

from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train_4, y_train_4)

predicted_values_4 = lasso_reg.predict(x_test_4)

# %%
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')
lasso_weights_df
# Out:
#        Features  Lasso_weight
# 0        RH_out     -0.041568
# 1          RH_8     -0.001878
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4      0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.005877
# 25         RH_1      0.007372

# %% [markdown]
# # Q20

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test_4, predicted_values_4))
round(rmse, 3)
# Out:
# 0.096
